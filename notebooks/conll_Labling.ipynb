# %%
import os
import sys
import json
import pandas as pd
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from src.services.label_conll import CoNLLLabeler

# %%
# Load normal JSON (not JSONL)
input_path = "../data/processed/processed_telegram_data.json"
with open(input_path, 'r', encoding='utf-8') as f:
    data = json.load(f)  # Only use json.load() once on the whole file

df = pd.DataFrame(data)

# %%
# Initialize and run labeling
output_path = "../data/labeled/labeled_conll_output.txt"
labeler = CoNLLLabeler(df=df, output_path=output_path, num_messages=50)
labeler.label_messages()
# Out:
# --- Starting CoNLL NER Labeling ---
# Label types: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O
# Instructions:
# - Press Enter for 'O' (outside).
# - Type 'skip' to skip a message.
# - Type 'quit' to save and exit.
# --------------------------------------------------
#
# --- Message 1 ---
# Cleaned Message: Saachi Electric Kettle Borosilicate Glass Body Overheat protection Automatic switch off w ዋጋ፦ ብር ውስን ፍሬ ነው ያለው አድራሻ ቢሮ ቁ SS በTelegram ለማዘዝ ይጠቀሙ ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን
# Tokens: ['Saachi', 'Electric', 'Kettle', 'Borosilicate', 'Glass', 'Body', 'Overheat', 'protection', 'Automatic', 'switch', 'off', 'w', 'ዋጋ፦', 'ብር', 'ውስን', 'ፍሬ', 'ነው', 'ያለው', 'አድራሻ', 'ቢሮ', 'ቁ', 'SS', 'በTelegram', 'ለማዘዝ', 'ይጠቀሙ', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን']
# ------------------------------
# ✅ Message labeled. Total labeled so far: 1
#
# --- Message 2 ---
# ...
